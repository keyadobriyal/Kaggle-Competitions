# %% [markdown]
# ## Prediction of Customer Churn Pbobability
#
# **Version 1.0**
#
# The notebook in fourth entry to competition I started with Basics to start with using Random Fore7r, before I test pipelione and ensemble
#
# **Version 2.0**
#
# Random Forests tend to struggle with this because they average predictions from many trees, which often pushes probabilities away from 0 and 1 toward the center.
# This version introduces Random Forest Calibration By applying Platt Scaling (Sigmoid calibration), turns a mathematical output into a reliable financial metric for churn prevention strategies.
#
# **Version 3.0**
#
# Introduced GridSearchCV: It no longer guesses the number of trees; it tests 50, 100, 150, 200, 250 and 300 to find the most accurate estimator for specific data.
#
# **Version 4.0**
#
# Introduced notebook pipeline using Balanced Random Forest (from imblearn) designed to:
# - Handle churn imbalance properly
# - Increase churn probability sensitivity
# - Optimize for ROC-AUC
# - Improve recall for churners
# - Provide calibrated probabilities
# - Use stratified CV
# - Automatically tune threshold
#
# **Version 5.0***
#
# Added multi-seed ensemble combining XGBoost + Random Forest, optimized for churn imbalance and probability separation.
# - XGBoost with scale_pos_weight
# - RandomForest with class_weight='balanced'
# - 3 seeds
# - 5-fold stratified CV
# - Rank normalization blending
# - Weight optimization
# - Threshold tuning for recall
#
# **Version 6.0**
#
# Added CatBoost to XGBoost and RF
#   3-model multi-seed ensemble:
# - XGBoost
# - Random Forest
# - CatBoost
# - 3 seeds
# - 5-fold stratified CV
# - Rank blending
# - Weight optimization
# - Threshold tuning
#
# **Version 7.0**
#
#
# Added LightGBM to the previous XGBoost + Random Forest + CatBoost multi-seed ensemble to evaluate 4 model ensemble, these four specific algorithms leverage different mathematical "perspectives" on your data:
# - XGBoost & LightGBM: These are "Gradient Boosted Decision Trees" (GBDT). They build trees sequentially, where each tree tries to correct the errors of the previous one. They are highly aggressive and excellent at finding complex patterns.
# - CatBoost: It uses a specialized technique called "Ordered Boosting" which is specifically designed to reduce bias when dealing with categorical variables. It often finds insights that XGB/LGB miss.
# - Random Forest: This is a "Bagging" model. Unlike the others, it builds many independent trees in parallel and averages them. It is much harder to overfit, making it a perfect "anchor" for your ensemble to prevent the boosting models from becoming too volatile.
#
# **Version 8.0**
#
# Added Feature Engineering along with automatic ensemble weight calculation, the model now has
# - Feature Engineering (tenure ratios, charge ratios, service counts)
# - Automatic Ensemble Weight Search
# - Multi-seed ensemble (XGB + LGBM + CatBoost + RF)
# - Rank blending
# - Grid search for optimal ensemble weights
#
# **Version 9.0**
#
# Improved pipeline by adding
# - Automatic feature generation
# - Multi-seed base models (XGB + LGBM + CatBoost + RF)
# - Out-of-fold predictions
# - Stacking meta-model (Logistic Regression)
# - Rank normalization
#
# The pipeline can be depicted:
#
# - Raw Data
# - Feature Engineering
# - Base Models (Level-1)
#
# --   ├── XGBoost
# --   ├── LightGBM
# --   ├── CatBoost
# --   └── RandomForest
#
# - OOF Predictions
# - Stacking Dataset
# - Meta Model (Level-2)
# - Logistic Regression
# - Final Predictions

# %%
# ============================================================
# 1. Imports
# ============================================================

import numpy as np
import pandas as pd
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import roc_auc_score
from sklearn.ensemble import RandomForestClassifier

from scipy.stats import rankdata

import xgboost as xgb
import lightgbm as lgb
from catboost import CatBoostClassifier

SEEDS = [11, 42, 77, 256]
N_FOLDS = 5
TARGET = "Churn"

# Set visual style
sns.set(style="whitegrid")

# %%
# =============================================================================
# 2. Data Loading 
# =============================================================================
train = pd.read_csv("/kaggle/input/competitions/playground-series-s6e3/train.csv")
test = pd.read_csv("/kaggle/input/competitions/playground-series-s6e3/test.csv")

print("Completed Loading Data ...")
print("Train shape:", train.shape)
print("Test shape :", test.shape)

test_ids = test["id"].copy()

# Descriptive Statistics
stats = train.describe()

print("\nDescriptive Stats:\n", stats)
# Out:
# Completed Loading Data ...
# Train shape: (594194, 21)
# Test shape : (254655, 20)
#
# Descriptive Stats:
#                    id  SeniorCitizen         tenure  MonthlyCharges  \
# count  594194.000000  594194.000000  594194.000000   594194.000000
# mean   297096.500000       0.114102      36.577258       65.866223
# std    171529.177262       0.317936      25.061922       31.067444
# min         0.000000       0.000000       1.000000       18.250000
# 25%    148548.250000       0.000000      12.000000       29.900000
# 50%    297096.500000       0.000000      35.000000       74.100000
# 75%    445644.750000       0.000000      62.000000       90.800000
# max    594193.000000       1.000000      72.000000      118.750000
#
#         TotalCharges
# count  594194.000000
# mean     2494.377057
# std      2353.916710
# min        18.800000
# 25%       639.650000
# 50%      1433.650000
# 75%      4263.800000
# max      8684.800000

# %%
# ============================================================
# 3. Automatic Feature Engineering
# ============================================================

def create_features(df):
    df["avg_monthly_charge"] = df["TotalCharges"] / (df["tenure"] + 1)
    df["charge_tenure_ratio"] = df["MonthlyCharges"] / (df["tenure"] + 1)
    df["totalcharge_monthly_ratio"] = df["TotalCharges"] / (df["MonthlyCharges"] + 1)
    df["tenure_monthly_product"] = df["tenure"] * df["MonthlyCharges"]
    df["tenure_square"] = df["tenure"] ** 2
    service_cols = [
        'PhoneService','OnlineSecurity','OnlineBackup',
        'DeviceProtection','TechSupport','StreamingTV',
        'StreamingMovies'
    ]
    df["num_services"] = df[service_cols].astype(str).apply(
        lambda x: (x!="No").sum(),
        axis=1
    )
    df["service_ratio"] = df["num_services"] / 7
    return df


train = create_features(train)
test  = create_features(test)

# %%
# ============================================================
# 4. Cleaning and Encoding
# ============================================================
for df in [train, test]:

    df["TotalCharges"] = pd.to_numeric(df["TotalCharges"], errors="coerce")

    df["TotalCharges"].fillna(
        df["TotalCharges"].median(),
        inplace=True
    )

cat_cols = train.select_dtypes(include="object").columns.tolist()
cat_cols.remove(TARGET)

encoders = {}

for col in cat_cols:

    le = LabelEncoder()

    train[col] = le.fit_transform(train[col].astype(str))
    test[col]  = le.transform(test[col].astype(str))

    encoders[col] = le


train[TARGET] = train[TARGET].map({"Yes":1,"No":0})

X = train.drop(["id", TARGET], axis=1)
y = train[TARGET]

X_test = test.drop(["id"], axis=1)

print("Churn Rate:", y.mean())

neg = (y == 0).sum()
pos = (y == 1).sum()

scale_pos_weight = neg / pos

print("scale_pos_weight:", scale_pos_weight)
# Out:
# Churn Rate: 0.225207592133209
# scale_pos_weight: 3.440347638939746

# %%
# ============================================================
# 5. Multi-Seed Training - XGB + RF + CatBoost + LGBM
# ============================================================
all_oof_xgb = []
all_oof_lgb = []
all_oof_rf  = []
all_oof_cat = []

all_test_xgb = []
all_test_lgb = []
all_test_rf  = []
all_test_cat = []


for seed in SEEDS:

    print("\n" + "="*60)
    print(f"TRAINING WITH SEED {seed}")
    print("="*60)

    skf = StratifiedKFold(
        n_splits=N_FOLDS,
        shuffle=True,
        random_state=seed
    )

    oof_xgb = np.zeros(len(X))
    oof_lgb = np.zeros(len(X))
    oof_rf  = np.zeros(len(X))
    oof_cat = np.zeros(len(X))

    test_xgb = np.zeros(len(X_test))
    test_lgb = np.zeros(len(X_test))
    test_rf  = np.zeros(len(X_test))
    test_cat = np.zeros(len(X_test))

    for fold,(tr_idx,val_idx) in enumerate(skf.split(X,y)):

        print(f"\n----- Fold {fold+1}/{N_FOLDS} -----")

        X_tr, X_val = X.iloc[tr_idx], X.iloc[val_idx]
        y_tr, y_val = y.iloc[tr_idx], y.iloc[val_idx]


        # ================= XGBOOST =================

        xgb_model = xgb.XGBClassifier(
            n_estimators=5000,
            learning_rate=0.0125,
            max_depth=6,
            min_child_weight=5,
            subsample=0.8,
            colsample_bytree=0.8,
            gamma=0.1,
            reg_alpha=0.1,
            reg_lambda=1,
            scale_pos_weight=scale_pos_weight,
            tree_method="hist",
            eval_metric="auc",
            random_state=seed,
            n_jobs=-1
        )

        xgb_model.fit(
            X_tr,y_tr,
            eval_set=[(X_val,y_val)],
            verbose=False
        )

        xgb_pred = xgb_model.predict_proba(X_val)[:,1]
        oof_xgb[val_idx] = xgb_pred

        print(f"XGB Fold AUC: {roc_auc_score(y_val,xgb_pred):.5f}")

        test_xgb += xgb_model.predict_proba(X_test)[:,1] / N_FOLDS


        # ================= LIGHTGBM =================

        lgb_model = lgb.LGBMClassifier(
            n_estimators=5000,
            learning_rate=0.0125,
            num_leaves=64,
            subsample=0.8,
            colsample_bytree=0.8,
            class_weight="balanced",
            random_state=seed,
            verbosity=-1,
            force_row_wise=True
        )

        lgb_model.fit(
            X_tr,y_tr,
            eval_set=[(X_val,y_val)],
            eval_metric="auc",
            callbacks=[lgb.early_stopping(200)]
        )

        lgb_pred = lgb_model.predict_proba(X_val)[:,1]
        oof_lgb[val_idx] = lgb_pred

        print(f"LGB Fold AUC: {roc_auc_score(y_val,lgb_pred):.5f}")

        test_lgb += lgb_model.predict_proba(X_test)[:,1] / N_FOLDS


        # ================= RANDOM FOREST =================

        rf = RandomForestClassifier(
            n_estimators=800,
            min_samples_leaf=3,
            class_weight="balanced",
            random_state=seed,
            n_jobs=-1
        )

        rf.fit(X_tr,y_tr)

        rf_pred = rf.predict_proba(X_val)[:,1]
        oof_rf[val_idx] = rf_pred

        print(f"RF Fold AUC : {roc_auc_score(y_val,rf_pred):.5f}")

        test_rf += rf.predict_proba(X_test)[:,1] / N_FOLDS


        # ================= CATBOOST =================

        cat = CatBoostClassifier(
            iterations=10000,
            learning_rate=0.0125,
            depth=6,
            eval_metric="AUC",
            auto_class_weights="Balanced",
            random_seed=seed,
            verbose=False
        )

        cat.fit(
            X_tr,y_tr,
            eval_set=(X_val,y_val),
            early_stopping_rounds=200
        )

        cat_pred = cat.predict_proba(X_val)[:,1]
        oof_cat[val_idx] = cat_pred

        print(f"CAT Fold AUC: {roc_auc_score(y_val,cat_pred):.5f}")

        test_cat += cat.predict_proba(X_test)[:,1] / N_FOLDS


    print("\nSeed Summary")
    print("---------------------------")

    print("XGB AUC:", roc_auc_score(y,oof_xgb))
    print("LGB AUC:", roc_auc_score(y,oof_lgb))
    print("RF  AUC:", roc_auc_score(y,oof_rf))
    print("CAT AUC:", roc_auc_score(y,oof_cat))


    # Store results
    all_oof_xgb.append(oof_xgb)
    all_oof_lgb.append(oof_lgb)
    all_oof_rf.append(oof_rf)
    all_oof_cat.append(oof_cat)

    all_test_xgb.append(test_xgb)
    all_test_lgb.append(test_lgb)
    all_test_rf.append(test_rf)
    all_test_cat.append(test_cat)
# Out:
# ============================================================
# TRAINING WITH SEED 11
# ============================================================
#
# ----- Fold 1/5 -----
# XGB Fold AUC: 0.91481
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [2478]	valid_0's auc: 0.914816	valid_0's binary_logloss: 0.369799
# LGB Fold AUC: 0.91482
# RF Fold AUC : 0.90923
# CAT Fold AUC: 0.91524
#
# ----- Fold 2/5 -----
# XGB Fold AUC: 0.91601
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [2601]	valid_0's auc: 0.915801	valid_0's binary_logloss: 0.3686
# LGB Fold AUC: 0.91580
# RF Fold AUC : 0.90968
# CAT Fold AUC: 0.91618
#
# ----- Fold 3/5 -----
# XGB Fold AUC: 0.91678
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [2652]	valid_0's auc: 0.916802	valid_0's binary_logloss: 0.368613
# LGB Fold AUC: 0.91680
# RF Fold AUC : 0.91126
# CAT Fold AUC: 0.91702
#
# ----- Fold 4/5 -----
# XGB Fold AUC: 0.91711
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [2710]	valid_0's auc: 0.916848	valid_0's binary_logloss: 0.367171
# LGB Fold AUC: 0.91685
# RF Fold AUC : 0.91132
# CAT Fold AUC: 0.91739
#
# ----- Fold 5/5 -----
# XGB Fold AUC: 0.91604
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [2174]	valid_0's auc: 0.916008	valid_0's binary_logloss: 0.371825
# LGB Fold AUC: 0.91601
# RF Fold AUC : 0.91056
# CAT Fold AUC: 0.91611
#
# Seed Summary
# ---------------------------
# XGB AUC: 0.9161454593728877
# LGB AUC: 0.9160490422615197
# RF  AUC: 0.9104092022080791
# CAT AUC: 0.9163862742483647
#
# ============================================================
# TRAINING WITH SEED 42
# ============================================================
#
# ----- Fold 1/5 -----
# XGB Fold AUC: 0.91570
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [2377]	valid_0's auc: 0.915615	valid_0's binary_logloss: 0.370089
# LGB Fold AUC: 0.91562
# RF Fold AUC : 0.90985
# CAT Fold AUC: 0.91594
#
# ----- Fold 2/5 -----
# XGB Fold AUC: 0.91682
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [2647]	valid_0's auc: 0.916837	valid_0's binary_logloss: 0.3701
# LGB Fold AUC: 0.91684
# RF Fold AUC : 0.91136
# CAT Fold AUC: 0.91721
#
# ----- Fold 3/5 -----
# XGB Fold AUC: 0.91636
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [2327]	valid_0's auc: 0.916169	valid_0's binary_logloss: 0.369507
# LGB Fold AUC: 0.91617
# RF Fold AUC : 0.91052
# CAT Fold AUC: 0.91650
#
# ----- Fold 4/5 -----
# XGB Fold AUC: 0.91728
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [2239]	valid_0's auc: 0.917053	valid_0's binary_logloss: 0.365977
# LGB Fold AUC: 0.91705
# RF Fold AUC : 0.91135
# CAT Fold AUC: 0.91748
#
# ----- Fold 5/5 -----
# XGB Fold AUC: 0.91455
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [2234]	valid_0's auc: 0.914517	valid_0's binary_logloss: 0.372217
# LGB Fold AUC: 0.91452
# RF Fold AUC : 0.90887
# CAT Fold AUC: 0.91481
#
# Seed Summary
# ---------------------------
# XGB AUC: 0.9161360022103398
# LGB AUC: 0.9160299070579283
# RF  AUC: 0.9103872553912737
# CAT AUC: 0.9163779622209
#
# ============================================================
# TRAINING WITH SEED 77
# ============================================================
#
# ----- Fold 1/5 -----
# XGB Fold AUC: 0.91634
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [2702]	valid_0's auc: 0.916119	valid_0's binary_logloss: 0.368661
# LGB Fold AUC: 0.91612
# RF Fold AUC : 0.91045
# CAT Fold AUC: 0.91657
#
# ----- Fold 2/5 -----
# XGB Fold AUC: 0.91625
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [1976]	valid_0's auc: 0.91608	valid_0's binary_logloss: 0.370656
# LGB Fold AUC: 0.91608
# RF Fold AUC : 0.91049
# CAT Fold AUC: 0.91634
#
# ----- Fold 3/5 -----
# XGB Fold AUC: 0.91450
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [2021]	valid_0's auc: 0.914436	valid_0's binary_logloss: 0.372173
# LGB Fold AUC: 0.91444
# RF Fold AUC : 0.90869
# CAT Fold AUC: 0.91472
#
# ----- Fold 4/5 -----
# XGB Fold AUC: 0.91666
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [2457]	valid_0's auc: 0.916559	valid_0's binary_logloss: 0.368777
# LGB Fold AUC: 0.91656
# RF Fold AUC : 0.91083
# CAT Fold AUC: 0.91677
#
# ----- Fold 5/5 -----
# XGB Fold AUC: 0.91731
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [1843]	valid_0's auc: 0.917273	valid_0's binary_logloss: 0.368794
# LGB Fold AUC: 0.91727
# RF Fold AUC : 0.91167
# CAT Fold AUC: 0.91767
#
# Seed Summary
# ---------------------------
# XGB AUC: 0.9162074817134946
# LGB AUC: 0.9160863270871868
# RF  AUC: 0.9104233969647827
# CAT AUC: 0.9164095031830659
#
# ============================================================
# TRAINING WITH SEED 256
# ============================================================
#
# ----- Fold 1/5 -----
# XGB Fold AUC: 0.91655
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [2465]	valid_0's auc: 0.916402	valid_0's binary_logloss: 0.368594
# LGB Fold AUC: 0.91640
# RF Fold AUC : 0.91055
# CAT Fold AUC: 0.91677
#
# ----- Fold 2/5 -----
# XGB Fold AUC: 0.91495
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [1847]	valid_0's auc: 0.915027	valid_0's binary_logloss: 0.372957
# LGB Fold AUC: 0.91503
# RF Fold AUC : 0.90953
# CAT Fold AUC: 0.91512
#
# ----- Fold 3/5 -----
# XGB Fold AUC: 0.91732
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [2174]	valid_0's auc: 0.917233	valid_0's binary_logloss: 0.369471
# LGB Fold AUC: 0.91723
# RF Fold AUC : 0.91138
# CAT Fold AUC: 0.91748
#
# ----- Fold 4/5 -----
# XGB Fold AUC: 0.91565
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [2402]	valid_0's auc: 0.915419	valid_0's binary_logloss: 0.369695
# LGB Fold AUC: 0.91542
# RF Fold AUC : 0.90967
# CAT Fold AUC: 0.91582
#
# ----- Fold 5/5 -----
# XGB Fold AUC: 0.91673
# Training until validation scores don't improve for 200 rounds
# Early stopping, best iteration is:
# [2097]	valid_0's auc: 0.91645	valid_0's binary_logloss: 0.368259
# LGB Fold AUC: 0.91645
# RF Fold AUC : 0.91075
# CAT Fold AUC: 0.91691
#
# Seed Summary
# ---------------------------
# XGB AUC: 0.9162360483436169
# LGB AUC: 0.916098716183496
# RF  AUC: 0.9103706909569003
# CAT AUC: 0.9164155978631372

# %%
# ============================================================
# 6. Average Prediction
# ============================================================
oof_xgb = np.mean(all_oof_xgb, axis=0)
oof_lgb = np.mean(all_oof_lgb, axis=0)
oof_rf  = np.mean(all_oof_rf, axis=0)
oof_cat = np.mean(all_oof_cat, axis=0)

test_xgb = np.mean(all_test_xgb, axis=0)
test_lgb = np.mean(all_test_lgb, axis=0)
test_rf  = np.mean(all_test_rf, axis=0)
test_cat = np.mean(all_test_cat, axis=0)

print("XGB AUC:", roc_auc_score(y,oof_xgb))
print("LGB AUC:", roc_auc_score(y,oof_lgb))
print("RF  AUC:", roc_auc_score(y,oof_rf))
print("CAT AUC:", roc_auc_score(y,oof_cat))
# Out:
# XGB AUC: 0.9164989478140855
# LGB AUC: 0.9163906455323969
# RF  AUC: 0.9115041758054925
# CAT AUC: 0.9166411511505466

# %%
# ============================================================
# 7. Rank Normalization
# ============================================================
import numpy as np
import pandas as pd
from scipy.stats import rankdata

def rank_norm(x):
    x = np.array(x)
    return rankdata(x) / len(x)

# OOF rank normalization
oof_xgb_r = rank_norm(oof_xgb)
oof_lgb_r = rank_norm(oof_lgb)
oof_rf_r  = rank_norm(oof_rf)
oof_cat_r = rank_norm(oof_cat)

# Test rank normalization
test_xgb_r = rank_norm(test_xgb)
test_lgb_r = rank_norm(test_lgb)
test_rf_r  = rank_norm(test_rf)
test_cat_r = rank_norm(test_cat)

# ============================================================
# Create Stacking Dataset
# ============================================================
stack_train = pd.DataFrame({
    "xgb": oof_xgb_r,
    "lgb": oof_lgb_r,
    "rf":  oof_rf_r,
    "cat": oof_cat_r
})

stack_test = pd.DataFrame({
    "xgb": test_xgb_r,
    "lgb": test_lgb_r,
    "rf":  test_rf_r,
    "cat": test_cat_r
})

# %%
# ============================================================
# 8. Meta Model Stacking
# ============================================================

from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import roc_auc_score

# Ensure y is pandas Series
y = pd.Series(y)

meta_oof = np.zeros(len(stack_train))
meta_test = np.zeros(len(stack_test))

skf = StratifiedKFold(
    n_splits=5,
    shuffle=True,
    random_state=42
)

for fold,(tr_idx,val_idx) in enumerate(skf.split(stack_train,y)):

    print(f"\nMeta Fold {fold+1}")

    X_tr = stack_train.iloc[tr_idx]
    X_val = stack_train.iloc[val_idx]

    y_tr = y.iloc[tr_idx]
    y_val = y.iloc[val_idx]

    meta_model = LogisticRegression(
        max_iter=1000,
        solver="lbfgs"
    )

    meta_model.fit(X_tr,y_tr)

    meta_oof[val_idx] = meta_model.predict_proba(X_val)[:,1]

    meta_test += meta_model.predict_proba(stack_test)[:,1] / skf.n_splits

    fold_auc = roc_auc_score(y_val, meta_oof[val_idx])
    print("Meta AUC:", fold_auc)


print("\nFinal Stacking AUC:")
print(roc_auc_score(y, meta_oof))
# Out:
# Meta Fold 1
# Meta AUC: 0.9163932818757662
#
# Meta Fold 2
# Meta AUC: 0.9174085523708837
#
# Meta Fold 3
# Meta AUC: 0.9168854828396581
#
# Meta Fold 4
# Meta AUC: 0.9179263491676505
#
# Meta Fold 5
# Meta AUC: 0.9151273203126337
#
# Final Stacking AUC:
# 0.9167417736456223

# %%
# =============================================================================
# 9. Submission
# =============================================================================
submission = pd.DataFrame({

    "id": test_ids,
    "Churn_Probability": meta_test

})

submission.to_csv("submission.csv", index=False)

submission.head(20)
# Out:
#         id  Churn_Probability
# 0   594194           0.077846
# 1   594195           0.000812
# 2   594196           0.106449
# 3   594197           0.002671
# 4   594198           0.517383
# 5   594199           0.187589
# 6   594200           0.854539
# 7   594201           0.003151
# 8   594202           0.036684
# 9   594203           0.330550
# 10  594204           0.003614
# 11  594205           0.037530
# 12  594206           0.183218
# 13  594207           0.836127
# 14  594208           0.002432
# 15  594209           0.022485
# 16  594210           0.496322
# 17  594211           0.001844
# 18  594212           0.852540
# 19  594213           0.225276
